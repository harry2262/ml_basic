# %%
print("hello")
# Out:
# hello

# %%
print("heloo")
# Out:
# heloo

# %% [markdown]
# # iiiiii
#
# this is markdown use
# we can return to commamnd mode by esc button and then pressing m for markdown
# esc+b for one cell down
# esc+a for one cell above
# esc+dd for deletion

# %%
import numpy as np

# %%
from matplotlib import pyplot

# %%
import pandas as pd

# %%
df = pd.read_csv("43 - heart-disease.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# use of matplotlib

# %%
df.age.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
df1 = pd.read_csv("test.csv")

# %%
df1
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.33               1                  0.33
# 1              1                  0.00               5                  0.00
# 2              1                  0.00               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.50               1                  0.00
# ..           ...                   ...             ...                   ...
# 115            1                  0.29               1                  0.00
# 116            1                  0.40               1                  0.00
# 117            1                  0.00               2                  0.00
# 118            0                  0.17               1                  0.00
# 119            1                  0.44               1                  0.00
#
# ...

# %%
df1.describe()
# Out:
#        profile pic  nums/length username  fullname words  \
# count   120.000000            120.000000      120.000000
# mean      0.758333              0.179917        1.550000
# std       0.429888              0.241492        1.187116
# min       0.000000              0.000000        0.000000
# 25%       1.000000              0.000000        1.000000
# 50%       1.000000              0.000000        1.000000
# 75%       1.000000              0.330000        2.000000
# max       1.000000              0.890000        9.000000
#
#        nums/length fullname  name==username  description length  external URL  \
# count            120.000000      120.000000          120.000000    120.000000
# mean               0.071333        0.041667           27.200000      0.100000
# std                0.209429        0.200664           42.588632      0.301258
# min                0.000000        0.000000            0.000000      0.000000
# ...

# %%
df1.shape
# Out:
# (120, 12)
